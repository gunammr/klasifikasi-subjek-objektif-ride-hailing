# %%
import pandas as pd

# %%
df = pd.read_csv("undersampling_result.csv")

# %%
df.info()
df.head(5)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 604 entries, 0 to 603
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  604 non-null    int64
#  1   review      604 non-null    str
#  2   label       604 non-null    int64
# dtypes: int64(2), str(1)
# memory usage: 14.3 KB
#    Unnamed: 0                                             review  label
# 0           0  tolang pelanggan terrsayang mohon diperhatikan...      1
# 1           1  keamanan kenyamanan konsumen perhatikan bnyk a...      0
# 2           2  buset nungguin pesenan gacoan jam 1049 sampe j...      0
# 3           3  terimakasih gercep ramah baru pertama kali mak...      1
# 4           4  aplikasi boncos tarif minimum menyentuh 10200 ...      1

# %%
import indo_normalizer
from indo_normalizer import Normalizer

# %%
normalizer = Normalizer()
# Out:
# Korpus 'c:\mine-pro\pkb-ride\.venv\Lib\site-packages\indo_normalizer\corpus\common_words.txt' berhasil dimuat. (18122 kata)
# Korpus 'c:\mine-pro\pkb-ride\.venv\Lib\site-packages\indo_normalizer\corpus\slangs.csv' berhasil dimuat. (1284 pasangan)

# %%
def indo_normalize(text):
    normalized_text, _ = normalizer.normalize_text(str(text))
    return normalized_text

# %%
df['review'] = df['review'].apply(indo_normalize)

# %%
df
# Out:
#      Unnamed: 0                                             review  label
# 0             0  orang pelanggan terbayang mohon diperhatikanla...      1
# 1             1  keamanan kenyamanan konsumen perhatikan bnyk a...      0
# 2             2  buset menunggu pesenan gacoan jam soal sampai ...      0
# 3             3  terimakasih gercep ramah baru pertama kali mem...      1
# 4             4  aplikasi boncos tarif minimum menyentuh zoo la...      1
# ..          ...                                                ...    ...
# 599         599  gila grab lama lama resep grabcar lama banget ...      1
# 600         600  aku harap penumpang melihat rating gojek bukan...      1
# 601         601  pelayanan mohon perbaikijangan biar kan pelang...      1
# 602         602  info management maxim driver pakai aplikasi ma...      0
# 603         603  mengira cuman saja ternyata banyak komplain di...      1
#
# [604 rows x 3 columns]

# %%
df_original = pd.read_csv("undersampling_result.csv")

# %%
df_original['review_normal'] = df_original['review_normal']

hasil, perubahan = normalizer.normalize_text(sample)

print("ASLI:")
print(sample)

print("\nHASIL:")
print(hasil)

print("\nPERUBAHAN:")
print(perubahan)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\mine-pro\pkb-ride\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
